# %%
import json
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    "demo_testing2",
    bootstrap_servers=["13.60.193.70:9092"],
    value_deserializer=lambda x: json.loads(x.decode("utf-8")),
)

# %%
for c in consumer:
    try:
        print(c.value)
    except json.JSONDecodeError:
        print("Skipping invalid JSON message")
# Out:
# {'name': 'test', 'age': 20}
# {'Index': 'NSEI', 'Date': '2018-08-13', 'Open': 11369.59961, 'High': 11406.29981, 'Low': 11340.29981, 'Close': 11355.75, 'Adj Close': 11355.75, 'Volume': 246900.0, 'CloseUSD': 113.5575}
# {'Index': 'HSI', 'Date': '2012-06-21', 'Open': 19480.71094, 'High': 19495.53906, 'Low': 19258.10938, 'Close': 19265.07031, 'Adj Close': 19265.07031, 'Volume': 1298230800.0, 'CloseUSD': 2504.4591403}
# {'Index': 'IXIC', 'Date': '2018-05-22', 'Open': 7420.850098, 'High': 7432.529785, 'Low': 7370.330078, 'Close': 7378.459961, 'Adj Close': 7378.459961, 'Volume': 1908280000.0, 'CloseUSD': 7378.459961}
# {'Index': 'N225', 'Date': '2011-06-29', 'Open': 9767.910156, 'High': 9797.259766, 'Low': 9734.660156, 'Close': 9797.259766, 'Adj Close': 9797.259766, 'Volume': 123400000.0, 'CloseUSD': 97.97259766}
# {'Index': 'N225', 'Date': '1984-11-08', 'Open': 11166.91992, 'High': 11166.91992, 'Low': 11166.91992, 'Close': 11166.91992, 'Adj Close': 11166.91992, 'Volume': 0.0, 'CloseUSD': 111.6691992}
# {'Index': '399001.SZ', 'Date': '1998-12-08', 'Open': 3127.0, 'High': 3155.290039, 'Low': 3121.689941, 'Close': 3148.02002, 'Adj Close': 3147.984619, 'Volume': 0.0, 'CloseUSD': 503.6832032}
# {'Index': 'J203.JO', 'Date': '2015-11-18', 'Open': 51981.64844, 'High': 51981.64844, 'Low': 51415.94141, 'Close': 51654.53906, 'Adj Close': 51654.53906, 'Volume': 0.0, 'CloseUSD': 3615.8177342}
# {'Index': '399001.SZ', 'Date': '2017-05-24', 'Open': 9722.040039, 'High': 9812.459961, 'Low': 9609.410156, 'Close': 9812.459961, 'Adj Close': 9812.349609, 'Volume': 659800.0, 'CloseUSD': 1569.99359376}
# {'Index': 'NYA', 'Date': '2020-07-07', 'Open': 12056.20996, 'High': 12107.9502, 'Low': 11979.76953, 'Close': 11990.13965, 'Adj Close': 11990.13965, 'Volume': 4563700000.0, 'CloseUSD': 11990.13965}
# {'Index': 'GSPTSE', 'Date': '2001-08-23', 'Open': 7526.399902, 'High': 7563.5, 'Low': 7522.799805, 'Close': 7542.399902, 'Adj Close': 7542.399902, 'Volume': 8558270000.0, 'CloseUSD': 6260.19191866}
# {'Index': 'TWII', 'Date': '2014-08-15', 'Open': 9243.669922, 'High': 9243.669922, 'Low': 9172.910156, 'Close': 9206.80957, 'Adj Close': 9206.775391, 'Volume': 1924300.0, 'CloseUSD': 368.2723828}
# {'Index': 'N100', 'Date': '2011-06-07', 'Open': 692.390015, 'High': 695.830017, 'Low': 691.390015, 'Close': 693.02002, 'Adj Close': 693.02002, 'Volume': 201739400.0, 'CloseUSD': 845.4844244000001}
# {'Index': 'NYA', 'Date': '1978-09-27', 'Open': 605.97998, 'High': 605.97998, 'Low': 605.97998, 'Close': 605.97998, 'Adj Close': 605.97998, 'Volume': 0.0, 'CloseUSD': 605.97998}
# {'Index': 'N225', 'Date': '1993-03-16', 'Open': 18104.33984, 'High': 18117.08984, 'Low': 17945.2207, 'Close': 17968.30078, 'Adj Close': 17968.30078, 'Volume': 0.0, 'CloseUSD': 179.6830078}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 for c in consumer:
#       2     try:
#       3         print(c.value)
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/anaconda3/lib/python3.11/selectors.py:561, in KqueueSelector.select(self, timeout)
#     559 ready = []
#     560 try:
# --> 561     kev_list = self._selector.control(None, max_ev, timeout)
#     562 except InterruptedError:
#     563     return ready
#
# KeyboardInterrupt:

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-stock-market-tutorial-youtube-darshil/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[5], line 2
#       1 for count, i in enumerate(consumer):
# ----> 2     with s3.open("s3://kafka-stock-market-tutorial-youtube-darshil/stock_market_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#
# File ~/anaconda3/lib/python3.11/site-packages/fsspec/spec.py:1932, in AbstractBufferedFile.close(self)
#    1930 else:
#    1931     if not self.forced:
# -> 1932         self.flush(force=True)
#    1934     if self.fs is not None:
#    1935         self.fs.invalidate_cache(self.path)
#
# File ~/anaconda3/lib/python3.11/site-packages/fsspec/spec.py:1803, in AbstractBufferedFile.flush(self, force)
#    1800         self.closed = True
#    1801         raise
# -> 1803 if self._upload_chunk(final=force) is not False:
#    1804     self.offset += self.buffer.seek(0, 2)
#    1805     self.buffer = io.BytesIO()
#
# File ~/anaconda3/lib/python3.11/site-packages/s3fs/core.py:2368, in S3File._upload_chunk(self, final)
#    2365     self.parts.append(part_header)
#    2367 if self.autocommit and final:
# -> 2368     self.commit()
#    2369 return not final
#
# File ~/anaconda3/lib/python3.11/site-packages/s3fs/core.py:2386, in S3File.commit(self)
#    2384     if self.acl:
#    2385         kw["ACL"] = self.acl
# -> 2386     write_result = self._call_s3("put_object", **kw)
#    2387 else:
#    2388     raise RuntimeError
#
# File ~/anaconda3/lib/python3.11/site-packages/s3fs/core.py:2231, in S3File._call_s3(self, method, *kwarglist, **kwargs)
#    2230 def _call_s3(self, method, *kwarglist, **kwargs):
# -> 2231     return self.fs.call_s3(method, self.s3_additional_kwargs, *kwarglist, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~/anaconda3/lib/python3.11/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~/anaconda3/lib/python3.11/site-packages/s3fs/core.py:362, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     360 logger.debug("CALL: %s - %s - %s", method.__name__, akwarglist, kw2)
#     361 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 362 return await _error_wrapper(
#     363     method, kwargs=additional_kwargs, retries=self.retries
#     364 )
#
# File ~/anaconda3/lib/python3.11/site-packages/s3fs/core.py:142, in _error_wrapper(func, args, kwargs, retries)
#     140         err = e
#     141 err = translate_boto_error(err)
# --> 142 raise err
#
# File ~/anaconda3/lib/python3.11/site-packages/s3fs/core.py:113, in _error_wrapper(func, args, kwargs, retries)
#     111 for i in range(retries):
#     112     try:
# --> 113         return await func(*args, **kwargs)
#     114     except S3_RETRYABLE_ERRORS as e:
#     115         err = e
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/client.py:388, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     384     maybe_compress_request(
#     385         self.meta.config, request_dict, operation_model
#     386     )
#     387     apply_request_checksum(request_dict)
# --> 388     http, parsed_response = await self._make_request(
#     389         operation_model, request_dict, request_context
#     390     )
#     392 await self.meta.events.emit(
#     393     'after-call.{service_id}.{operation_name}'.format(
#     394         service_id=service_id, operation_name=operation_name
#    (...)
#     399     context=request_context,
#     400 )
#     402 if http.status_code >= 300:
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/client.py:416, in AioBaseClient._make_request(self, operation_model, request_dict, request_context)
#     412 async def _make_request(
#     413     self, operation_model, request_dict, request_context
#     414 ):
#     415     try:
# --> 416         return await self._endpoint.make_request(
#     417             operation_model, request_dict
#     418         )
#     419     except Exception as e:
#     420         await self.meta.events.emit(
#     421             'after-call-error.{service_id}.{operation_name}'.format(
#     422                 service_id=self._service_model.service_id.hyphenize(),
#    (...)
#     426             context=request_context,
#     427         )
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/endpoint.py:98, in AioEndpoint._send_request(self, request_dict, operation_model)
#      96 context = request_dict['context']
#      97 self._update_retries_context(context, attempts)
# ---> 98 request = await self.create_request(request_dict, operation_model)
#      99 success_response, exception = await self._get_response(
#     100     request, operation_model, context
#     101 )
#     102 while await self._needs_retry(
#     103     attempts,
#     104     operation_model,
#    (...)
#     107     exception,
#     108 ):
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/endpoint.py:86, in AioEndpoint.create_request(self, params, operation_model)
#      82     service_id = operation_model.service_model.service_id.hyphenize()
#      83     event_name = 'request-created.{service_id}.{op_name}'.format(
#      84         service_id=service_id, op_name=operation_model.name
#      85     )
# ---> 86     await self._event_emitter.emit(
#      87         event_name,
#      88         request=request,
#      89         operation_name=operation_model.name,
#      90     )
#      91 prepared_request = self.prepare_request(request)
#      92 return prepared_request
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/hooks.py:66, in AioHierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#      63 logger.debug('Event %s: calling handler %s', event_name, handler)
#      65 # Await the handler if its a coroutine.
# ---> 66 response = await resolve_awaitable(handler(**kwargs))
#      67 responses.append((handler, response))
#      68 if stop_on_response and response is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/_helpers.py:15, in resolve_awaitable(obj)
#      13 async def resolve_awaitable(obj):
#      14     if inspect.isawaitable(obj):
# ---> 15         return await obj
#      17     return obj
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/signers.py:24, in AioRequestSigner.handler(self, operation_name, request, **kwargs)
#      19 async def handler(self, operation_name=None, request=None, **kwargs):
#      20     # This is typically hooked up to the "request-created" event
#      21     # from a client's event emitter.  When a new request is created
#      22     # this method is invoked to sign the request.
#      23     # Don't call this method directly.
# ---> 24     return await self.sign(operation_name, request)
#
# File ~/anaconda3/lib/python3.11/site-packages/aiobotocore/signers.py:88, in AioRequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#      85     else:
#      86         raise e
# ---> 88 auth.add_auth(request)
#
# File ~/anaconda3/lib/python3.11/site-packages/botocore/auth.py:418, in SigV4Auth.add_auth(self, request)
#     416 def add_auth(self, request):
#     417     if self.credentials is None:
# --> 418         raise NoCredentialsError()
#     419     datetime_now = datetime.datetime.utcnow()
#     420     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials
